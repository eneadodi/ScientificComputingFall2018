# %%
import convergent_sums as c
import matplotlib.pyplot as plt
import math
import numpy as np

# %% [markdown]
# # HW06
# ##### Enea Dodi
# ##### 10/12/2018
# ###### Instructions:
# > Modify your class ConvergentSum so that evaluate also stores all partial sums in a list attribute .partials.
# Modify your class ConvergentSum to add a new method .plot(self) that runs .evaluate() if necessary, then plots the partial sums using matplotlib. Reference CW 6 for ideas how to do this. For the horizontal axis of the plot, enumerate the number of terms of each partial sum kk from 11 to NN. Resize the vertical axis using the axis method a.set(ylim=(ymin, ymax)) to be between 0 and 4. Draw a dashed line at y=\piy=π as a reference. Use the axis method .grid(True) to turn the grid lines on for the plot.
# For each series in HW 5 (and HW 4), plot the converging partial sums in a notebook convergent_plots.ipynb. Which sum converges the fastest?
#
# In this assignment, we will use the class we created in convergent_sums.py and plot how the y values (the value at every iteration of the convergent sums) converge to pi. We will compare all three of the terms and analyze which one reaches the value of pi faster.

# %%
term1 = c.ConvergentSum(c.term_1, start = 1)
term1.plot()

# %%
term2 = c.ConvergentSum(c.term_2)
term2.plot()

# %%
term3 = c.ConvergentSum(c.term_3)
term3.plot()

# %% [markdown]
# ## Analysis
# The former cells make three different objects of class ConvergentSum, each with a different function that sums to pi. Of the three functions, term_3:
# > $$4\sum_{k=1}^\infty \left[ \frac{4(-1)^{k+1}}{5^{2k+1}(2k + 1)} - \frac{(-1)^{k+1}}{239^{2k+1}(2k + 1)} \right]$$
#
# Seems to be the function which converges to pi the fastest. The values of the three terms once abs(a/val) > self.tolerance are:
# * term1 -> 3.1416083613006816
# * term2 -> 3.1415997738115062
# * term3 -> 3.1415917721821778
#
# and the difference from math.pi for each equation is:
# * term1 -> -1.5707710888435145e-05
# * term2 -> -7.1202217131194345e-06
# * term3 -> 8.814076153385031e-07
#
# Thus, term3 converges to pi the fastest and once abs(a/val) > self.tolerance, term3 is still the most accurate!
